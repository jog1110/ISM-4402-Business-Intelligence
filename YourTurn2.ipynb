# %%
import pandas as pd
Location = "Desktop\POP01.xls"

# %%
df = pd.read_excel(Location)

# %%
df.head(10)
# Out:
#        Area_name  STCOU  POP010130F  POP010130D  POP010130N1  POP010130N2  \
# 0  UNITED STATES      0           0   123202624            0            0
# 1        ALABAMA   1000           0     2646248            0            0
# 2    Autauga, AL   1001           0       19694            0            0
# 3    Baldwin, AL   1003           0       28289            0            0
# 4    Barbour, AL   1005           0       32425            0            0
# 5       Bibb, AL   1007           0       20780            0            0
# 6     Blount, AL   1009           0       28020            0            0
# 7    Bullock, AL   1011           0       20016            0            0
# 8     Butler, AL   1013           0       30195            0            0
# 9    Calhoun, AL   1015           0       55611            0            0
#
#    POP010140F  POP010140D  POP010140N1  POP010140N2  ...  POP010200N1  \
# 0           0   132164569            0            0  ...            0
# ...
